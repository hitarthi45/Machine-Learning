# %% [markdown]
# <a href="https://colab.research.google.com/github/hitarthi45/Machine-Learning/blob/main/Experiment/ML_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
#load the dataset
data=fetch_openml('titanic',version=1,as_frame=True)
print(data)
# Out:
# {'data':       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# ...

# %%
data['feature_names']
# Out:
# ['pclass',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked',
#  'boat',
#  'body',
#  'home.dest']

# %%
data_f=data.frame.copy()

# %%
#Drop the empty value
data=data_f[['age','sex','fare','embarked','pclass','survived']].dropna()
print(data)
# Out:
#           age     sex      fare embarked  pclass survived
# 0     29.0000  female  211.3375        S       1        1
# 1      0.9167    male  151.5500        S       1        1
# 2      2.0000  female  151.5500        S       1        0
# 3     30.0000    male  151.5500        S       1        0
# 4     25.0000  female  151.5500        S       1        0
# ...       ...     ...       ...      ...     ...      ...
# 1301  45.5000    male    7.2250        C       3        0
# 1304  14.5000  female   14.4542        C       3        0
# 1306  26.5000    male    7.2250        C       3        0
# 1307  27.0000    male    7.2250        C       3        0
# 1308  29.0000    male    7.8750        S       3        0
#
# [1043 rows x 6 columns]

# %%
set(list(data['embarked']))
# Out:
# {'C', 'Q', 'S'}

# %%
#Label Encoding
le=LabelEncoder()
data['embarked_le']=le.fit_transform(data['embarked'])

# %%
data.columns
# Out:
# Index(['age', 'sex', 'fare', 'embarked', 'pclass', 'survived', 'embarked_le'], dtype='object')

# %%
data['embarked_le']
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1301    0
# 1304    0
# 1306    0
# 1307    0
# 1308    2
# Name: embarked_le, Length: 1043, dtype: int64

# %%
#OneHotEncoder
ohe=OneHotEncoder()
df_ohe=pd.get_dummies(data,columns=['sex'])
df_ohe
# Out:
#           age      fare embarked  pclass survived  embarked_le  sex_female  \
# 0     29.0000  211.3375        S       1        1            2        True
# 1      0.9167  151.5500        S       1        1            2       False
# 2      2.0000  151.5500        S       1        0            2        True
# 3     30.0000  151.5500        S       1        0            2       False
# 4     25.0000  151.5500        S       1        0            2        True
# ...       ...       ...      ...     ...      ...          ...         ...
# 1301  45.5000    7.2250        C       3        0            0       False
# 1304  14.5000   14.4542        C       3        0            0        True
# 1306  26.5000    7.2250        C       3        0            0       False
# 1307  27.0000    7.2250        C       3        0            0       False
# 1308  29.0000    7.8750        S       3        0            2       False
#
#       sex_male
# 0        False
# 1         True
# 2        False
# ...

# %%
#load the dataset of diabetes
from sklearn.datasets import load_diabetes

# %%
data=load_diabetes(as_frame=True)
data=data.frame
print(data)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6  target
# ...

# %%
#statistic of data
data.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#get correlation in-between the features
corr=data.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# threeblue-onebrown

# %%
#feature Importance
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
import pandas as pd

# %%
data=load_diabetes(as_frame=True)
data=data.frame
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='object')

# %%
X_train,X_test,y_train,y_test=train_test_split(data.drop('target',axis=1),data['target'],test_size=0.2,random_state=42)

# %%
tree=DecisionTreeRegressor(max_depth=3)
tree.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
importances=pd.Series(tree.feature_importances_,index=X_train.columns)
importances
# Out:
# age    0.000000
# sex    0.000000
# bmi    0.711521
# bp     0.000000
# s1     0.000000
# s2     0.021410
# s3     0.000000
# s4     0.023996
# s5     0.178897
# s6     0.064176
# dtype: float64
